# %%
import pandas as pd
#Importing pandas library

# %%
df=pd.read_csv("data.csv")
#Importing csv file named as data

# %%
df.head()
#Printing the first 5 rows of dataset
# Out:
#    Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0           0        0.0102         0.833       204600   0.434
# 1           1        0.1990         0.743       326933   0.359
# 2           2        0.0344         0.838       185707   0.412
# 3           3        0.6040         0.494       199413   0.338
# 4           4        0.1800         0.678       392893   0.561
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.021900    2    0.1650    -8.795     1       0.4310  150.062
# 1          0.006110    1    0.1370   -10.401     1       0.0794  160.083
# 2          0.000234    2    0.1590    -7.148     1       0.2890   75.044
# 3          0.510000    5    0.0922   -15.236     1       0.0261   86.468
# 4          0.512000    5    0.4390   -11.648     0       0.0694  174.004
#
#    time_signature  valence  target      song_title            artist
# 0             4.0    0.286       1        Mask Off            Future
# ...

# %%
df.head(10)
#Printing the first 10 rows of dataset
# Out:
#    Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0           0       0.01020         0.833       204600   0.434
# 1           1       0.19900         0.743       326933   0.359
# 2           2       0.03440         0.838       185707   0.412
# 3           3       0.60400         0.494       199413   0.338
# 4           4       0.18000         0.678       392893   0.561
# 5           5       0.00479         0.804       251333   0.560
# 6           6       0.01450         0.739       241400   0.472
# 7           7       0.02020         0.266       349667   0.348
# 8           8       0.04810         0.603       202853   0.944
# 9           9       0.00208         0.836       226840   0.603
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.021900    2    0.1650    -8.795     1       0.4310  150.062
# 1          0.006110    1    0.1370   -10.401     1       0.0794  160.083
# ...

# %%
df.tail()
#Printing the last 5 rows of dataset
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 2012        2012       0.00106         0.584       274404   0.932
# 2013        2013       0.08770         0.894       182182   0.892
# 2014        2014       0.00857         0.637       207200   0.935
# 2015        2015       0.00164         0.557       185600   0.992
# 2016        2016       0.00281         0.446       204520   0.915
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 2012          0.002690    1    0.1290    -3.501     1        0.333   74.976
# 2013          0.001670    1    0.0528    -2.663     1        0.131  110.041
# 2014          0.003990    0    0.2140    -2.467     1        0.107  150.082
# 2015          0.677000    1    0.0913    -2.735     1        0.133  150.011
# 2016          0.000039    9    0.2180    -6.221     1        0.141  190.013
#
#       time_signature  valence  target                            song_title  \
# ...

# %%
df.tail(10)
#Printing the first 10 rows of dataset
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 2007        2007      0.002170         0.639       296276   0.978
# 2008        2008      0.054100         0.646       160408   0.714
# 2009        2009      0.004990         0.595       224000   0.837
# 2010        2010      0.002310         0.624       206013   0.971
# 2011        2011      0.000586         0.528       245053   0.879
# 2012        2012      0.001060         0.584       274404   0.932
# 2013        2013      0.087700         0.894       182182   0.892
# 2014        2014      0.008570         0.637       207200   0.935
# 2015        2015      0.001640         0.557       185600   0.992
# 2016        2016      0.002810         0.446       204520   0.915
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 2007          0.112000   11    0.0838    -2.376     1       0.0730  144.986
# 2008          0.000000    0    0.1340    -6.511     1       0.0378   97.957
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2017 entries, 0 to 2016
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        2017 non-null   int64
#  1   acousticness      2017 non-null   float64
#  2   danceability      2017 non-null   float64
#  3   duration_ms       2017 non-null   int64
#  4   energy            2017 non-null   float64
#  5   instrumentalness  2017 non-null   float64
#  6   key               2017 non-null   int64
#  7   liveness          2017 non-null   float64
#  8   loudness          2017 non-null   float64
#  9   mode              2017 non-null   int64
#  10  speechiness       2017 non-null   float64
#  11  tempo             2017 non-null   float64
#  12  time_signature    2017 non-null   float64
#  13  valence           2017 non-null   float64
#  14  target            2017 non-null   int64
#  15  song_title        2017 non-null   object
# ...

# %%
df.sort_values('danceability')['song_title'].head(10)
#Sorting the values of danceability column then printing it with songtitle column
#Using head(10) to print the first 10 columns of songtitle
# Out:
# 729                                            Bumpy Road
# 532                                       Wake Bake Skate
# 817     Mozart: Requiem in D Minor, K. 626: VIII. Lacr...
# 1600           Trio Sonata in G Major, Wq. 144: I. Adagio
# 1598    Piano Quartet in E flat, Op.47: 3. Andante can...
# 522                                                 Outro
# 1348                 Be My Valentine (feat. Dickie Allen)
# 1464                                           Right Here
# 1313                                      Senseless Order
# 1306                                                 Ruin
# Name: song_title, dtype: object

# %%
df.sort_values('danceability')[['song_title','artist']].head(10)
#Printing top 10 values under song_title and artist column
# Out:
#                                              song_title  \
# 729                                          Bumpy Road
# 532                                     Wake Bake Skate
# 817   Mozart: Requiem in D Minor, K. 626: VIII. Lacr...
# 1600         Trio Sonata in G Major, Wq. 144: I. Adagio
# 1598  Piano Quartet in E flat, Op.47: 3. Andante can...
# 522                                               Outro
# 1348               Be My Valentine (feat. Dickie Allen)
# 1464                                         Right Here
# 1313                                    Senseless Order
# 1306                                               Ruin
#
#                          artist
# 729            Destruction Unit
# 532                      FIDLAR
# 817        Nikolaus Harnoncourt
# 1600  Carl Philipp Emanuel Bach
# 1598            Robert Schumann
# 522                         M83
# 1348                     Brojob
# 1464              Keys N Krates
# 1313         Signs of the Swarm
# ...

# %%
df.sort_values('duration_ms')[['song_title','artist']].tail(10)
#Sorting dursation time of songs
#Printing last 10 values under song_title and artist column
#Using tail(10) to print last 10 values
#The songs printed are the 10 most longest songs
# Out:
#                                              song_title  \
# 1602  String Quintet in C Major, Op. 29: II. Adagio ...
# 304                              Night on Bald Mountain
# 858                              Night on Bald Mountain
# 404                     Who Is He And What Is He To You
# 335                                              Zombie
# 1565                                      Gloomy Sunday
# 1603  Viola Sonata in C Minor: III. Andante con vari...
# 819                                 Southern Man - Live
# 695   Music Is the Answer - Original Extended 12-Inc...
# 1535                                The Nearness of You
#
#                             artist
# 1602          Ludwig van Beethoven
# 304              Modest Mussorgsky
# 858              Modest Mussorgsky
# 404                Creative Source
# 335                      Fela Kuti
# 1565             Branford Marsalis
# 1603             Felix Mendelssohn
# 819   Crosby, Stills, Nash & Young
# ...

# %%
df_filt=df[df['duration_ms']<400000]
#Filtering the values under duration column
#Printing values under 4000000ms(400s)

# %%
df_filt
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0              0       0.01020         0.833       204600   0.434
# 1              1       0.19900         0.743       326933   0.359
# 2              2       0.03440         0.838       185707   0.412
# 3              3       0.60400         0.494       199413   0.338
# 4              4       0.18000         0.678       392893   0.561
# ...          ...           ...           ...          ...     ...
# 2012        2012       0.00106         0.584       274404   0.932
# 2013        2013       0.08770         0.894       182182   0.892
# 2014        2014       0.00857         0.637       207200   0.935
# 2015        2015       0.00164         0.557       185600   0.992
# 2016        2016       0.00281         0.446       204520   0.915
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0             0.021900    2    0.1650    -8.795     1       0.4310  150.062
# ...

# %%
df_filt2=df_filt.sort_values('energy')[['song_title','artist','duration_ms']].tail(10)
#Sorting the values under energy column
#Printing the last 10 rows

# %%
df_filt2
# Out:
#                song_title                    artist  duration_ms
# 1296         Black Colors       Victim Of Deception       247533
# 1681                Hated                 Beartooth       211430
# 1328  Down into the Abyss               Conjonctive       256920
# 1680             Paranoia         A Day To Remember       200677
# 1332      Beautiful Agony          Within The Ruins       271560
# 2015        First Contact                Twin Moons       185600
# 1347           Unanswered           Suicide Silence       135653
# 1297    A Darkened Gospel      A Wake in Providence       311217
# 1322           Pitchblack  Walking Dead On Broadway       221776
# 1299        No Absolution         Thy Art Is Murder       201783

# %%
df_filtered= df.sort_values('duration_ms')[['song_title','artist','duration_ms']].tail(10)
df_filtered.to_csv('filtered_data.csv')#Creating and exporting a new file that has sorted values of the duration time

# %%
df_filt3=df[df['energy']>0.4]
#Filtering the values under energy column
#Printing values under 0.4
df_filt3
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0              0       0.01020         0.833       204600   0.434
# 2              2       0.03440         0.838       185707   0.412
# 4              4       0.18000         0.678       392893   0.561
# 5              5       0.00479         0.804       251333   0.560
# 6              6       0.01450         0.739       241400   0.472
# ...          ...           ...           ...          ...     ...
# 2012        2012       0.00106         0.584       274404   0.932
# 2013        2013       0.08770         0.894       182182   0.892
# 2014        2014       0.00857         0.637       207200   0.935
# 2015        2015       0.00164         0.557       185600   0.992
# 2016        2016       0.00281         0.446       204520   0.915
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0             0.021900    2    0.1650    -8.795     1       0.4310  150.062
# ...

# %%
df_filt3[['energy','song_title']]
#Printing values under song_title and energy
# Out:
#       energy                            song_title
# 0      0.434                              Mask Off
# 2      0.412                          Xanny Family
# 4      0.561                        Parallel Lines
# 5      0.560                              Sneakin’
# 6      0.472                           Childs Play
# ...      ...                                   ...
# 2012   0.932   Like A Bitch - Kill The Noise Remix
# 2013   0.892                                 Candy
# 2014   0.935  Habit - Dack Janiels & Wenzday Remix
# 2015   0.992                         First Contact
# 2016   0.915                    I Wanna Get Better
#
# [1830 rows x 2 columns]

# %%
df_filt4=df[df['duration_ms']<300000]
#Filtering the values under duration column
#Printing values under 300000

df_filt4
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0              0       0.01020         0.833       204600   0.434
# 2              2       0.03440         0.838       185707   0.412
# 3              3       0.60400         0.494       199413   0.338
# 5              5       0.00479         0.804       251333   0.560
# 6              6       0.01450         0.739       241400   0.472
# ...          ...           ...           ...          ...     ...
# 2012        2012       0.00106         0.584       274404   0.932
# 2013        2013       0.08770         0.894       182182   0.892
# 2014        2014       0.00857         0.637       207200   0.935
# 2015        2015       0.00164         0.557       185600   0.992
# 2016        2016       0.00281         0.446       204520   0.915
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0             0.021900    2    0.1650    -8.795     1       0.4310  150.062
# ...

# %%
df_fastest=df.sort_values('tempo')[['song_title','artist']].tail(10)
#Sorting values under tempo column
#Printing only song title and artist column
#Using tail(10) to print the last 10 columns
#The last 10 columns will be having the most tempo hence they would be the top 10 fastest songs
print("The TOP 10 Fastest Songs are:")
df_fastest
# Out:
# The TOP 10 Fastest Songs are:
#                 song_title            artist
# 1802             Mad Love.              JoJo
# 102         Willing & Able        Disclosure
# 1339  The Shaping Sickness  Shadow of Intent
# 826     Living Every Dream            Antwon
# 809        Tupelo - Part 1       Pop Staples
# 1711               Amazing     Big Time Rush
# 1960            Puppy Love      Donny Osmond
# 718            Hannah Hunt   Vampire Weekend
# 124       Danger and Dread        Brown Bird
# 412                 Lazuli       Beach House

# %%
df_Drake=df[df['artist']=="Drake"]
#Identifying the artist Drake

# %%
df_Drake
#Printing only rows that have artists named Drake
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 5              5       0.00479         0.804       251333   0.560
# 6              6       0.01450         0.739       241400   0.472
# 37            37       0.05650         0.853       205879   0.547
# 117          117       0.00257         0.896       267024   0.623
# 154          154       0.00157         0.790       217707   0.676
# 158          158       0.19000         0.735       275840   0.410
# 168          168       0.04720         0.849       217693   0.408
# 440          440       0.36900         0.662       236733   0.571
# 589          589       0.04250         0.790       173160   0.531
# 676          676       0.00300         0.766       227027   0.453
# 717          717       0.00349         0.772       227880   0.407
# 779          779       0.76300         0.707       275227   0.709
# 1016        1016       0.01030         0.745       143214   0.822
# ...

# %%
df_energy=df_Drake[df['energy']>0.5]
#Filtering energy column of songs which has Drake as an artists
#Printing rows that has more than 0.5 energy
df_energy[['song_title']]
#Printing only song title column
# Out:
# <ipython-input-71-0b3468cbeaba>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_energy=df_Drake[df['energy']>0.5]
#                    song_title
# 5                    Sneakin’
# 37                    Jumpman
# 117             Hotline Bling
# 154                 Big Rings
# 440                 Headlines
# 589   Started From the Bottom
# 779   0 To 100 / The Catch Up
# 1016         Skepta Interlude
# 1218          Best I Ever Had
# 1223                Take Care

# %%
df_instrumentalness=df.sort_values('instrumentalness')[['instrumentalness','song_title','artist']].head(10)
df_instrumentalness
#Sorting the values under instrumentalness column
#Printing only columns named as inrtumentalness,song_title and artist
#Printing the first 10 rows
# Out:
#       instrumentalness              song_title            artist
# 1008               0.0               Toothache            Jaykae
# 481                0.0              Ready 2 Go    Martin Solveig
# 966                0.0                 Bugatti          Ace Hood
# 1129               0.0  Sugar, We're Goin Down      Fall Out Boy
# 1487               0.0  High Without Your Love             Loote
# 1130               0.0               Centuries      Fall Out Boy
# 1483               0.0                   Young  The Chainsmokers
# 1134               0.0            Dance, Dance      Fall Out Boy
# 1481               0.0                    Kiwi      Harry Styles
# 1489               0.0          1-800-273-8255             Logic

# %%
#Finding top 10 most occuring artists

Top10 = df[['artist']]
Top10.groupby('artist').mean()
# Out:
# Empty DataFrame
# Columns: []
# ...
